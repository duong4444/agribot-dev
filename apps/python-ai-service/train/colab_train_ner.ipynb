# %% [markdown]
# # 🌾 Smart Agriculture NER Training
#
# **Train Named Entity Recognition model on Google Colab**
#
# ---
#
# ## 📋 Overview
#
# - **Model:** PhoBERT (Vietnamese BERT)
# - **Task:** Named Entity Recognition (14 entity types)
# - **Data:** 10,000 samples (auto-generated)
# - **GPU:** Tesla T4/P100 (FREE)
# - **Time:** ~40-60 minutes
#
# ---
#
# ## 🚀 Quick Start
#
# 1. **Runtime → Change runtime type → T4 GPU**
# 2. **Upload your `ner_data_augmented.csv`** (or use auto-generation)
# 3. **Run all cells** (Runtime → Run all)
# 4. **Download trained model** (last cell)
#
# ---
